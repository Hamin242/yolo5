# %%
import os
import shutil 
import xml.etree.ElementTree as ET
import pandas as pd

# %%
after_data_path='D:/hm/Projoects/yolo5/data/images/train_0721/'
before_data_path='D:/Data/Image/CAM00'

# %%
import glob
model_list= os.listdir(before_data_path)
model_list
# Out:
# ['CA',
#  'CB',
#  'CT',
#  'CU',
#  'CV',
#  'CW',
#  'FA',
#  'FB',
#  'FC',
#  'FD',
#  'FE',
#  'FG',
#  'FH',
#  'FJ',
#  'FM',
#  'FN',
#  'FP',
#  'FQ',
#  'FR',
#  'FT',
#  'FU',
#  'FV',
#  'FW',
#  'GB',
#  'HA',
#  'JC',
#  'JD',
#  'JE',
#  'JG',
#  'JH',
#  'JJ',
#  'JM',
#  'JN',
#  'JP',
#  'JR',
#  'KA',
#  'KB',
#  'LA',
#  'LB',
#  'LC',
#  'LD',
#  'LE',
#  'LF',
#  'LG',
#  'LJ',
#  'MA',
#  'MB',
#  'PC',
#  'PD',
#  'PE',
#  'PG',
#  'PK',
#  'PM',
#  'PN',
#  'PP',
#  'QA',
#  'QB',
#  'QT',
#  'QU',
#  'QV',
#  'QW',
#  'RC',
#  'RE',
#  'RF',
#  'RG',
#  'RI',
#  'RK',
#  'RL',
#  'RM',
#  'RP',
#  'RQ',
#  'RR',
#  'SA',
#  'SB',
#  'SC',
#  'SD',
#  'SE',
#  'SF',
#  'SG',
#  'SH',
#  'SJ',
#  'SK',
#  'SL',
#  'SM',
#  'SN',
#  'SP',
#  'SQ',
#  'SR',
#  'SS',
#  'ST',
#  'SU',
#  'SV',
#  'SW',
#  'TE',
#  'UC',
#  'UD',
#  'UE',
#  'UK',
#  'UM',
#  'UP',
#  'UT',
#  'UW',
#  'UX',
#  'VA',
#  'VB',
#  'VC',
#  'VD',
#  'VF',
#  'VG',
#  'VK',
#  'VM',
# ...

# %%
for i in model_list:
#     print(i)
#     print(after_data_path+i.split('\\')[-1])
#     print(after_data_path+i.split('\\')[-2]+'_'+i.split('\\')[-3]+'_'+i.split('\\')[-1])
    shutil.copy(i,after_data_path+i.split('\\')[-1])

# %%
tmp=set()
for i in model_list:
    tmpp=i.split('\\')[-1]
    tmp.add(tmpp[:2])
tmp
# Out:
# {'FG',
#  'FH',
#  'GB',
#  'HA',
#  'KB',
#  'LA',
#  'LC',
#  'LD',
#  'LE',
#  'MA',
#  'PC',
#  'PD',
#  'PM',
#  'PP',
#  'QA',
#  'QB',
#  'QT',
#  'QU',
#  'QV',
#  'RC',
#  'RE',
#  'RG',
#  'RI',
#  'RL',
#  'RQ',
#  'RR',
#  'SA',
#  'SB',
#  'SC',
#  'SD',
#  'SE',
#  'SF',
#  'SH',
#  'SP',
#  'SQ',
#  'SU',
#  'SV',
#  'SW',
#  'UC',
#  'UM',
#  'UT',
#  'VC',
#  'VD',
#  'VG',
#  'VM',
#  'VP',
#  'YC',
#  'YD',
#  'YE'}

# %%
after_xml_path='D:/hm/Projoects/yolo5/data/labels/train_0721/'
before_xml_path='D:/Data/EEI/Training_Data/Annotations/'

# %%
model_list_xml=os.listdir(before_xml_path)
model_list_xml
# Out:
# ['FG_CAM00_220024.xml',
#  'FG_CAM00_220025.xml',
#  'FG_CAM00_220026.xml',
#  'FG_CAM00_220027.xml',
#  'FG_CAM00_220028.xml',
#  'FG_CAM00_220029.xml',
#  'FG_CAM00_220030.xml',
#  'FG_CAM00_220031.xml',
#  'FG_CAM00_220033.xml',
#  'FG_CAM00_220034.xml',
#  'FG_CAM00_220035.xml',
#  'FG_CAM00_220036.xml',
#  'FG_CAM00_220037.xml',
#  'FG_CAM00_220038.xml',
#  'FG_CAM00_220039.xml',
#  'FG_CAM00_220040.xml',
#  'FG_CAM00_220041.xml',
#  'FG_CAM00_220042.xml',
#  'FG_CAM00_220043.xml',
#  'FG_CAM00_220044.xml',
#  'FG_CAM01_220024.xml',
#  'FG_CAM01_220025.xml',
#  'FG_CAM01_220026.xml',
#  'FG_CAM01_220027.xml',
#  'FG_CAM01_220028.xml',
#  'FG_CAM01_220029.xml',
#  'FG_CAM01_220030.xml',
#  'FG_CAM01_220031.xml',
#  'FG_CAM01_220033.xml',
#  'FG_CAM01_220034.xml',
#  'FG_CAM01_220035.xml',
#  'FG_CAM01_220036.xml',
#  'FG_CAM01_220037.xml',
#  'FG_CAM01_220038.xml',
#  'FG_CAM01_220039.xml',
#  'FG_CAM01_220040.xml',
#  'FG_CAM01_220041.xml',
#  'FG_CAM01_220042.xml',
# ...

# %%
for i in model_list_xml:
#     print(after_xml_path+i)
#     print(before_xml_path+i)
    shutil.copy(before_xml_path+i,after_xml_path+i)
